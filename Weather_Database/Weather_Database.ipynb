# %%
# Import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import the requests library
import requests

# Import the API key from the config.py file
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time

# Import the citipy module to determine city based on given latitude and longitude
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
type(lat_lngs)
# Out:
# zip

# %%
# Unzip the lat_lngs zip object into a list
coordinates = list(lat_lngs)

# %%
type(coordinates)
# Out:
# list

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4cd321fcf416788b4ffd30d712c434a4

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc
                         })

# If an error is experienced, skip the city.
    except:
        print("City '" + city.title() + "' not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | pitea
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | biak
# Processing Record 5 of Set 1 | birobidzhan
# Processing Record 6 of Set 1 | taolanaro
# City 'Taolanaro' not found. Skipping...
# Processing Record 7 of Set 1 | ornskoldsvik
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | camana
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | vanavara
# Processing Record 16 of Set 1 | santa maria
# Processing Record 17 of Set 1 | zyryanka
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | gamba
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | altamira
# Processing Record 25 of Set 1 | leningradskiy
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | clyde river
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | burgeo
# Processing Record 30 of Set 1 | puerto del rosario
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | aswan
# Processing Record 33 of Set 1 | port augusta
# Processing Record 34 of Set 1 | leticia
# Processing Record 35 of Set 1 | japura
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | sao jose da coroa grande
# Processing Record 38 of Set 1 | amderma
# City 'Amderma' not found. Skipping...
# Processing Record 39 of Set 1 | ogaminana
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | tabukiniberu
# City 'Tabukiniberu' not found. Skipping...
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | barentsburg
# City 'Barentsburg' not found. Skipping...
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | moindou
# Processing Record 48 of Set 1 | mirina
# City 'Mirina' not found. Skipping...
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | sao desiderio
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | les cayes
# Processing Record 3 of Set 2 | borogontsy
# Processing Record 4 of Set 2 | narsaq
# Processing Record 5 of Set 2 | tartagal
# Processing Record 6 of Set 2 | xuddur
# Processing Record 7 of Set 2 | san
# Processing Record 8 of Set 2 | shieli
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | simav
# Processing Record 11 of Set 2 | aflu
# City 'Aflu' not found. Skipping...
# Processing Record 12 of Set 2 | zlatoustovsk
# City 'Zlatoustovsk' not found. Skipping...
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | illoqqortoormiut
# City 'Illoqqortoormiut' not found. Skipping...
# Processing Record 21 of Set 2 | churapcha
# Processing Record 22 of Set 2 | qurayyat
# Processing Record 23 of Set 2 | certeju de sus
# Processing Record 24 of Set 2 | tabas
# Processing Record 25 of Set 2 | dire dawa
# Processing Record 26 of Set 2 | wilmington
# Processing Record 27 of Set 2 | biltine
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | shimoda
# Processing Record 30 of Set 2 | nargana
# Processing Record 31 of Set 2 | mattawa
# Processing Record 32 of Set 2 | akdagmadeni
# Processing Record 33 of Set 2 | conceicao do araguaia
# Processing Record 34 of Set 2 | pisco
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | talcahuano
# Processing Record 40 of Set 2 | sao felix do xingu
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | avera
# Processing Record 43 of Set 2 | lakes entrance
# Processing Record 44 of Set 2 | vaitupu
# City 'Vaitupu' not found. Skipping...
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | obihiro
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | itoman
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | meyungs
# City 'Meyungs' not found. Skipping...
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | port macquarie
# Processing Record 4 of Set 3 | arkhara
# Processing Record 5 of Set 3 | schladming
# Processing Record 6 of Set 3 | mongu
# Processing Record 7 of Set 3 | yulara
# Processing Record 8 of Set 3 | tual
# Processing Record 9 of Set 3 | chernyshevskiy
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | bilibino
# Processing Record 13 of Set 3 | nelson bay
# Processing Record 14 of Set 3 | adrar
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | salalah
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | jalu
# Processing Record 19 of Set 3 | warmbad
# Processing Record 20 of Set 3 | helong
# Processing Record 21 of Set 3 | luderitz
# Processing Record 22 of Set 3 | ossora
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | vanimo
# Processing Record 25 of Set 3 | brigantine
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | kiama
# Processing Record 28 of Set 3 | deputatskiy
# Processing Record 29 of Set 3 | beloha
# Processing Record 30 of Set 3 | saint-philippe
# Processing Record 31 of Set 3 | hobyo
# Processing Record 32 of Set 3 | blackwater
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | bam
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | lorengau
# Processing Record 37 of Set 3 | moree
# Processing Record 38 of Set 3 | bur gabo
# City 'Bur Gabo' not found. Skipping...
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | celestun
# Processing Record 41 of Set 3 | san cristobal
# Processing Record 42 of Set 3 | sentyabrskiy
# City 'Sentyabrskiy' not found. Skipping...
# Processing Record 43 of Set 3 | sosnovo-ozerskoye
# Processing Record 44 of Set 3 | sovetskiy
# Processing Record 45 of Set 3 | bandarbeyla
# Processing Record 46 of Set 3 | tuktoyaktuk
# Processing Record 47 of Set 3 | broome
# Processing Record 48 of Set 3 | ngukurr
# City 'Ngukurr' not found. Skipping...
# Processing Record 49 of Set 3 | sicuani
# Processing Record 50 of Set 3 | port alfred
# Processing Record 1 of Set 4 | batagay-alyta
# Processing Record 2 of Set 4 | pokhara
# Processing Record 3 of Set 4 | lavrentiya
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | minudasht
# Processing Record 6 of Set 4 | porosozero
# Processing Record 7 of Set 4 | dedougou
# Processing Record 8 of Set 4 | college
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | anadyr
# Processing Record 11 of Set 4 | sola
# Processing Record 12 of Set 4 | aykhal
# Processing Record 13 of Set 4 | ulundi
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | grindavik
# Processing Record 16 of Set 4 | merauke
# Processing Record 17 of Set 4 | rassvet
# Processing Record 18 of Set 4 | krasnoborsk
# Processing Record 19 of Set 4 | severnyy
# Processing Record 20 of Set 4 | puerto carreno
# Processing Record 21 of Set 4 | pokrovsk
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | nobeoka
# Processing Record 24 of Set 4 | hofn
# Processing Record 25 of Set 4 | fort saint john
# City 'Fort Saint John' not found. Skipping...
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | ishinomaki
# Processing Record 28 of Set 4 | novozybkov
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | los llanos de aridane
# Processing Record 31 of Set 4 | ondorhaan
# City 'Ondorhaan' not found. Skipping...
# Processing Record 32 of Set 4 | kiruna
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | roy
# Processing Record 36 of Set 4 | cabra
# Processing Record 37 of Set 4 | norman wells
# Processing Record 38 of Set 4 | ust-tsilma
# Processing Record 39 of Set 4 | sao paulo de olivenca
# Processing Record 40 of Set 4 | codrington
# Processing Record 41 of Set 4 | taltal
# Processing Record 42 of Set 4 | kungurtug
# Processing Record 43 of Set 4 | puerto suarez
# Processing Record 44 of Set 4 | sur
# Processing Record 45 of Set 4 | alice springs
# Processing Record 46 of Set 4 | dekoa
# City 'Dekoa' not found. Skipping...
# Processing Record 47 of Set 4 | oussouye
# Processing Record 48 of Set 4 | mikulasovice
# Processing Record 49 of Set 4 | mecca
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | grand river south east
# City 'Grand River South East' not found. Skipping...
# Processing Record 2 of Set 5 | srednekolymsk
# Processing Record 3 of Set 5 | abu samrah
# Processing Record 4 of Set 5 | fortuna
# Processing Record 5 of Set 5 | klaksvik
# Processing Record 6 of Set 5 | praya
# Processing Record 7 of Set 5 | taksimo
# Processing Record 8 of Set 5 | sibolga
# Processing Record 9 of Set 5 | margate
# Processing Record 10 of Set 5 | barcelos
# Processing Record 11 of Set 5 | vardo
# Processing Record 12 of Set 5 | culaba
# Processing Record 13 of Set 5 | gizo
# Processing Record 14 of Set 5 | fukue
# Processing Record 15 of Set 5 | saskylakh
# Processing Record 16 of Set 5 | carnarvon
# Processing Record 17 of Set 5 | geraldton
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | auki
# Processing Record 20 of Set 5 | cockburn town
# Processing Record 21 of Set 5 | puro
# Processing Record 22 of Set 5 | rawson
# Processing Record 23 of Set 5 | lugo
# Processing Record 24 of Set 5 | istok
# Processing Record 25 of Set 5 | vangaindrano
# Processing Record 26 of Set 5 | okato
# Processing Record 27 of Set 5 | luau
# Processing Record 28 of Set 5 | san quintin
# Processing Record 29 of Set 5 | manokwari
# Processing Record 30 of Set 5 | chumikan
# Processing Record 31 of Set 5 | kahului
# Processing Record 32 of Set 5 | padang
# Processing Record 33 of Set 5 | coihaique
# Processing Record 34 of Set 5 | torit
# Processing Record 35 of Set 5 | lima
# Processing Record 36 of Set 5 | compostela
# Processing Record 37 of Set 5 | rio novo do sul
# Processing Record 38 of Set 5 | colesberg
# Processing Record 39 of Set 5 | lompoc
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | kitimat
# Processing Record 42 of Set 5 | one hundred mile house
# City 'One Hundred Mile House' not found. Skipping...
# Processing Record 43 of Set 5 | linhares
# Processing Record 44 of Set 5 | dingle
# Processing Record 45 of Set 5 | limenaria
# Processing Record 46 of Set 5 | tumannyy
# City 'Tumannyy' not found. Skipping...
# Processing Record 47 of Set 5 | yarim
# Processing Record 48 of Set 5 | toropets
# Processing Record 49 of Set 5 | kenai
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | saldanha
# Processing Record 2 of Set 6 | katsuura
# Processing Record 3 of Set 6 | tateyama
# Processing Record 4 of Set 6 | jacksonville
# Processing Record 5 of Set 6 | midwest city
# Processing Record 6 of Set 6 | mangrol
# Processing Record 7 of Set 6 | pangnirtung
# Processing Record 8 of Set 6 | berdigestyakh
# Processing Record 9 of Set 6 | puerto gaitan
# Processing Record 10 of Set 6 | mar del plata
# Processing Record 11 of Set 6 | xai-xai
# Processing Record 12 of Set 6 | demyansk
# Processing Record 13 of Set 6 | taylor
# Processing Record 14 of Set 6 | rocha
# Processing Record 15 of Set 6 | belushya guba
# City 'Belushya Guba' not found. Skipping...
# Processing Record 16 of Set 6 | tuggurt
# City 'Tuggurt' not found. Skipping...
# Processing Record 17 of Set 6 | kapoeta
# Processing Record 18 of Set 6 | tuy hoa
# Processing Record 19 of Set 6 | calabozo
# Processing Record 20 of Set 6 | tocache
# Processing Record 21 of Set 6 | kartaly
# Processing Record 22 of Set 6 | manjacaze
# Processing Record 23 of Set 6 | benghazi
# Processing Record 24 of Set 6 | saint-joseph
# Processing Record 25 of Set 6 | mikhaylovka
# Processing Record 26 of Set 6 | constitucion
# Processing Record 27 of Set 6 | bonthe
# Processing Record 28 of Set 6 | kruisfontein
# Processing Record 29 of Set 6 | marcona
# City 'Marcona' not found. Skipping...
# Processing Record 30 of Set 6 | fremont
# Processing Record 31 of Set 6 | shizukuishi
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | yerbogachen
# Processing Record 34 of Set 6 | vengerovo
# Processing Record 35 of Set 6 | bavleny
# Processing Record 36 of Set 6 | pochutla
# Processing Record 37 of Set 6 | najran
# Processing Record 38 of Set 6 | bethel
# Processing Record 39 of Set 6 | fallingbostel
# Processing Record 40 of Set 6 | manaure
# Processing Record 41 of Set 6 | micheweni
# Processing Record 42 of Set 6 | mana
# Processing Record 43 of Set 6 | grand gaube
# Processing Record 44 of Set 6 | ancud
# Processing Record 45 of Set 6 | jaboatao
# Processing Record 46 of Set 6 | virginia beach
# Processing Record 47 of Set 6 | loreto
# Processing Record 48 of Set 6 | storsteinnes
# Processing Record 49 of Set 6 | sisimiut
# Processing Record 50 of Set 6 | laguna
# Processing Record 1 of Set 7 | atasu
# Processing Record 2 of Set 7 | phan rang
# City 'Phan Rang' not found. Skipping...
# Processing Record 3 of Set 7 | saint anthony
# Processing Record 4 of Set 7 | poum
# Processing Record 5 of Set 7 | fort nelson
# Processing Record 6 of Set 7 | faya
# Processing Record 7 of Set 7 | abu dhabi
# Processing Record 8 of Set 7 | hualmay
# Processing Record 9 of Set 7 | kushmurun
# Processing Record 10 of Set 7 | nizhneyansk
# City 'Nizhneyansk' not found. Skipping...
# Processing Record 11 of Set 7 | batalha
# Processing Record 12 of Set 7 | coquimbo
# Processing Record 13 of Set 7 | sao gabriel da cachoeira
# Processing Record 14 of Set 7 | amahai
# Processing Record 15 of Set 7 | sukhovolya
# Processing Record 16 of Set 7 | tsihombe
# City 'Tsihombe' not found. Skipping...
# Processing Record 17 of Set 7 | talakan
# Processing Record 18 of Set 7 | fayaoue
# Processing Record 19 of Set 7 | santa isabel do rio negro
# Processing Record 20 of Set 7 | ismailia
# Processing Record 21 of Set 7 | bukachacha
# Processing Record 22 of Set 7 | parrita
# Processing Record 23 of Set 7 | oranzherei
# Processing Record 24 of Set 7 | skalistyy
# City 'Skalistyy' not found. Skipping...
# Processing Record 25 of Set 7 | talnakh
# Processing Record 26 of Set 7 | lebu
# Processing Record 27 of Set 7 | ilulissat
# Processing Record 28 of Set 7 | ariquemes
# Processing Record 29 of Set 7 | nawalapitiya
# Processing Record 30 of Set 7 | kaeo
# Processing Record 31 of Set 7 | anshun
# Processing Record 32 of Set 7 | port-gentil
# Processing Record 33 of Set 7 | mahebourg
# Processing Record 34 of Set 7 | beatrice
# Processing Record 35 of Set 7 | vazhiny
# Processing Record 36 of Set 7 | isangel
# Processing Record 37 of Set 7 | palabuhanratu
# City 'Palabuhanratu' not found. Skipping...
# Processing Record 38 of Set 7 | miranorte
# City 'Miranorte' not found. Skipping...
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | asfi
# Processing Record 41 of Set 7 | comodoro rivadavia
# Processing Record 42 of Set 7 | basco
# Processing Record 43 of Set 7 | palana
# Processing Record 44 of Set 7 | makung
# City 'Makung' not found. Skipping...
# Processing Record 45 of Set 7 | saleaula
# City 'Saleaula' not found. Skipping...
# Processing Record 46 of Set 7 | umzimvubu
# City 'Umzimvubu' not found. Skipping...
# Processing Record 47 of Set 7 | luorong
# Processing Record 48 of Set 7 | asau
# Processing Record 49 of Set 7 | berlevag
# Processing Record 50 of Set 7 | kavieng
# Processing Record 1 of Set 8 | omsukchan
# Processing Record 2 of Set 8 | akyab
# Processing Record 3 of Set 8 | hope
# Processing Record 4 of Set 8 | grand centre
# City 'Grand Centre' not found. Skipping...
# Processing Record 5 of Set 8 | hambantota
# Processing Record 6 of Set 8 | zhigansk
# Processing Record 7 of Set 8 | shetpe
# Processing Record 8 of Set 8 | bow island
# Processing Record 9 of Set 8 | meadow lake
# Processing Record 10 of Set 8 | miranda
# Processing Record 11 of Set 8 | mandalgovi
# Processing Record 12 of Set 8 | ostrovnoy
# Processing Record 13 of Set 8 | mys shmidta
# City 'Mys Shmidta' not found. Skipping...
# Processing Record 14 of Set 8 | tautira
# Processing Record 15 of Set 8 | trelew
# Processing Record 16 of Set 8 | dalbandin
# Processing Record 17 of Set 8 | quelimane
# Processing Record 18 of Set 8 | killybegs
# Processing Record 19 of Set 8 | labuhan
# Processing Record 20 of Set 8 | saint-denis
# Processing Record 21 of Set 8 | nara
# Processing Record 22 of Set 8 | east london
# Processing Record 23 of Set 8 | salinopolis
# Processing Record 24 of Set 8 | huarmey
# Processing Record 25 of Set 8 | alofi
# Processing Record 26 of Set 8 | kyaikkami
# Processing Record 27 of Set 8 | piracanjuba
# Processing Record 28 of Set 8 | ruatoria
# City 'Ruatoria' not found. Skipping...
# Processing Record 29 of Set 8 | zykovo
# Processing Record 30 of Set 8 | chatellerault
# Processing Record 31 of Set 8 | manuk mangkaw
# Processing Record 32 of Set 8 | tikapur
# Processing Record 33 of Set 8 | lagoa
# Processing Record 34 of Set 8 | ouagadougou
# Processing Record 35 of Set 8 | barra do garcas
# Processing Record 36 of Set 8 | zlobin
# Processing Record 37 of Set 8 | paamiut
# Processing Record 38 of Set 8 | anito
# Processing Record 39 of Set 8 | alamosa
# Processing Record 40 of Set 8 | amapa
# Processing Record 41 of Set 8 | oyama
# Processing Record 42 of Set 8 | talaya
# Processing Record 43 of Set 8 | itarema
# Processing Record 44 of Set 8 | graham
# Processing Record 45 of Set 8 | yar-sale
# Processing Record 46 of Set 8 | trinidad
# Processing Record 47 of Set 8 | lasa
# Processing Record 48 of Set 8 | kaitong
# Processing Record 49 of Set 8 | chicama
# Processing Record 50 of Set 8 | lota
# Processing Record 1 of Set 9 | natchez
# Processing Record 2 of Set 9 | tukums
# Processing Record 3 of Set 9 | opuwo
# Processing Record 4 of Set 9 | emerald
# Processing Record 5 of Set 9 | shingu
# Processing Record 6 of Set 9 | jacareacanga
# Processing Record 7 of Set 9 | abnub
# Processing Record 8 of Set 9 | lolua
# City 'Lolua' not found. Skipping...
# Processing Record 9 of Set 9 | nome
# Processing Record 10 of Set 9 | tevriz
# Processing Record 11 of Set 9 | sedalia
# Processing Record 12 of Set 9 | leshukonskoye
# Processing Record 13 of Set 9 | easley
# Processing Record 14 of Set 9 | sumbawa
# City 'Sumbawa' not found. Skipping...
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | zarnesti
# Processing Record 17 of Set 9 | araouane
# Processing Record 18 of Set 9 | dunedin
# Processing Record 19 of Set 9 | gelemso
# Processing Record 20 of Set 9 | kizukuri
# Processing Record 21 of Set 9 | nan
# Processing Record 22 of Set 9 | julio de castilhos
# Processing Record 23 of Set 9 | chapleau
# Processing Record 24 of Set 9 | ust-kuyga
# Processing Record 25 of Set 9 | boyolangu
# Processing Record 26 of Set 9 | tuatapere
# Processing Record 27 of Set 9 | san jeronimo
# Processing Record 28 of Set 9 | serenje
# Processing Record 29 of Set 9 | rock sound
# Processing Record 30 of Set 9 | esperance
# Processing Record 31 of Set 9 | manggar
# Processing Record 32 of Set 9 | halifax
# Processing Record 33 of Set 9 | odienne
# Processing Record 34 of Set 9 | tahe
# Processing Record 35 of Set 9 | taoudenni
# Processing Record 36 of Set 9 | vermilion
# Processing Record 37 of Set 9 | sorland
# Processing Record 38 of Set 9 | touros
# Processing Record 39 of Set 9 | zuwarah
# Processing Record 40 of Set 9 | bathsheba
# Processing Record 41 of Set 9 | moose factory
# Processing Record 42 of Set 9 | sergeyevka
# Processing Record 43 of Set 9 | bambous virieux
# Processing Record 44 of Set 9 | bilma
# Processing Record 45 of Set 9 | roald
# Processing Record 46 of Set 9 | saint-francois
# Processing Record 47 of Set 9 | severodvinsk
# Processing Record 48 of Set 9 | guerrero negro
# Processing Record 49 of Set 9 | mutsamudu
# City 'Mutsamudu' not found. Skipping...
# Processing Record 50 of Set 9 | port lincoln
# Processing Record 1 of Set 10 | gazanjyk
# Processing Record 2 of Set 10 | hami
# Processing Record 3 of Set 10 | vostok
# Processing Record 4 of Set 10 | pacific grove
# Processing Record 5 of Set 10 | ternate
# Processing Record 6 of Set 10 | palmer
# Processing Record 7 of Set 10 | komsomolskiy
# Processing Record 8 of Set 10 | mari-turek
# Processing Record 9 of Set 10 | armidale
# Processing Record 10 of Set 10 | fairbanks
# Processing Record 11 of Set 10 | kamyaran
# Processing Record 12 of Set 10 | prado
# Processing Record 13 of Set 10 | nalut
# Processing Record 14 of Set 10 | marsa matruh
# Processing Record 15 of Set 10 | ust-maya
# Processing Record 16 of Set 10 | millinocket
# Processing Record 17 of Set 10 | sao filipe
# Processing Record 18 of Set 10 | golfito
# Processing Record 19 of Set 10 | nikolaevo
# Processing Record 20 of Set 10 | necochea
# Processing Record 21 of Set 10 | igrim
# Processing Record 22 of Set 10 | cozumel
# Processing Record 23 of Set 10 | attawapiskat
# City 'Attawapiskat' not found. Skipping...
# Processing Record 24 of Set 10 | bria
# Processing Record 25 of Set 10 | zabol
# Processing Record 26 of Set 10 | goderich
# Processing Record 27 of Set 10 | guozhen
# Processing Record 28 of Set 10 | maniitsoq
# Processing Record 29 of Set 10 | alyangula
# Processing Record 30 of Set 10 | oistins
# Processing Record 31 of Set 10 | jiangkou
# Processing Record 32 of Set 10 | darnah
# Processing Record 33 of Set 10 | louisbourg
# City 'Louisbourg' not found. Skipping...
# Processing Record 34 of Set 10 | chagda
# City 'Chagda' not found. Skipping...
# Processing Record 35 of Set 10 | mestia
# Processing Record 36 of Set 10 | ilembula
# Processing Record 37 of Set 10 | sinnamary
# Processing Record 38 of Set 10 | mayumba
# Processing Record 39 of Set 10 | umm lajj
# Processing Record 40 of Set 10 | itacarambi
# Processing Record 41 of Set 10 | saint-georges
# Processing Record 42 of Set 10 | buraydah
# Processing Record 43 of Set 10 | port hardy
# Processing Record 44 of Set 10 | karema
# Processing Record 45 of Set 10 | utiroa
# City 'Utiroa' not found. Skipping...
# Processing Record 46 of Set 10 | husavik
# Processing Record 47 of Set 10 | yarmouth
# Processing Record 48 of Set 10 | roebourne
# Processing Record 49 of Set 10 | piranhas
# Processing Record 50 of Set 10 | tidore
# City 'Tidore' not found. Skipping...
# Processing Record 1 of Set 11 | ketchikan
# Processing Record 2 of Set 11 | santiago del estero
# Processing Record 3 of Set 11 | matto
# City 'Matto' not found. Skipping...
# Processing Record 4 of Set 11 | gao
# Processing Record 5 of Set 11 | vetlanda
# Processing Record 6 of Set 11 | farafangana
# Processing Record 7 of Set 11 | katherine
# Processing Record 8 of Set 11 | bonavista
# Processing Record 9 of Set 11 | williamsburg
# Processing Record 10 of Set 11 | ixtapa
# Processing Record 11 of Set 11 | rungata
# City 'Rungata' not found. Skipping...
# Processing Record 12 of Set 11 | saint-augustin
# Processing Record 13 of Set 11 | natal
# Processing Record 14 of Set 11 | port keats
# Processing Record 15 of Set 11 | valdivia
# Processing Record 16 of Set 11 | sayat
# Processing Record 17 of Set 11 | ojinaga
# Processing Record 18 of Set 11 | santa rosa
# Processing Record 19 of Set 11 | chapais
# Processing Record 20 of Set 11 | zhangjiakou
# Processing Record 21 of Set 11 | kudat
# Processing Record 22 of Set 11 | moyo
# Processing Record 23 of Set 11 | somerset
# Processing Record 24 of Set 11 | nicoya
# Processing Record 25 of Set 11 | shirokiy
# Processing Record 26 of Set 11 | la asuncion
# Processing Record 27 of Set 11 | solnechnyy
# Processing Record 28 of Set 11 | iwanai
# Processing Record 29 of Set 11 | eregli
# Processing Record 30 of Set 11 | beja
# Processing Record 31 of Set 11 | clonakilty
# Processing Record 32 of Set 11 | porto novo
# Processing Record 33 of Set 11 | richard toll
# City 'Richard Toll' not found. Skipping...
# Processing Record 34 of Set 11 | tripoli
# Processing Record 35 of Set 11 | duku
# Processing Record 36 of Set 11 | atyashevo
# Processing Record 37 of Set 11 | svobodnyy
# Processing Record 38 of Set 11 | makakilo city
# Processing Record 39 of Set 11 | muzaffarabad
# Processing Record 40 of Set 11 | la ronge
# Processing Record 41 of Set 11 | ahuimanu
# Processing Record 42 of Set 11 | malanje
# Processing Record 43 of Set 11 | pitsunda
# Processing Record 44 of Set 11 | papar
# Processing Record 45 of Set 11 | nemuro
# Processing Record 46 of Set 11 | san policarpo
# Processing Record 47 of Set 11 | evensk
# Processing Record 48 of Set 11 | kilindoni
# Processing Record 49 of Set 11 | turayf
# Processing Record 50 of Set 11 | itaituba
# Processing Record 1 of Set 12 | sabang
# Processing Record 2 of Set 12 | floro
# Processing Record 3 of Set 12 | primo tapia
# Processing Record 4 of Set 12 | ca mau
# Processing Record 5 of Set 12 | olafsvik
# Processing Record 6 of Set 12 | marv dasht
# City 'Marv Dasht' not found. Skipping...
# Processing Record 7 of Set 12 | wajid
# Processing Record 8 of Set 12 | torbay
# Processing Record 9 of Set 12 | kariba
# Processing Record 10 of Set 12 | hopkinsville
# Processing Record 11 of Set 12 | dakoro
# Processing Record 12 of Set 12 | mehamn
# Processing Record 13 of Set 12 | mayskiy
# Processing Record 14 of Set 12 | hamilton
# Processing Record 15 of Set 12 | beisfjord
# Processing Record 16 of Set 12 | eldikan
# City 'Eldikan' not found. Skipping...
# Processing Record 17 of Set 12 | varnsdorf
# Processing Record 18 of Set 12 | gaomi
# Processing Record 19 of Set 12 | saint-louis
# Processing Record 20 of Set 12 | batsfjord
# Processing Record 21 of Set 12 | kharp
# Processing Record 22 of Set 12 | santa cruz cabralia
# Processing Record 23 of Set 12 | sackville
# Processing Record 24 of Set 12 | port blair
# Processing Record 25 of Set 12 | buritizeiro
# Processing Record 26 of Set 12 | pevek
# Processing Record 27 of Set 12 | alta floresta
# Processing Record 28 of Set 12 | kyzyl
# Processing Record 29 of Set 12 | fare
# Processing Record 30 of Set 12 | sale
# Processing Record 31 of Set 12 | yuanping
# Processing Record 32 of Set 12 | masterton
# Processing Record 33 of Set 12 | khilok
# Processing Record 34 of Set 12 | la ligua
# Processing Record 35 of Set 12 | estacion coahuila
# Processing Record 36 of Set 12 | ankazobe
# Processing Record 37 of Set 12 | bargal
# City 'Bargal' not found. Skipping...
# Processing Record 38 of Set 12 | lodja
# Processing Record 39 of Set 12 | nyandoma
# Processing Record 40 of Set 12 | perth
# Processing Record 41 of Set 12 | holme
# Processing Record 42 of Set 12 | tabiauea
# City 'Tabiauea' not found. Skipping...
# Processing Record 43 of Set 12 | nortelandia
# Processing Record 44 of Set 12 | bontang
# Processing Record 45 of Set 12 | kavaratti
# Processing Record 46 of Set 12 | ban nahin
# Processing Record 47 of Set 12 | oriximina
# Processing Record 48 of Set 12 | qaqortoq
# Processing Record 49 of Set 12 | bud
# Processing Record 50 of Set 12 | laplace
# Processing Record 1 of Set 13 | jinchengjiang
# City 'Jinchengjiang' not found. Skipping...
# Processing Record 2 of Set 13 | sherlovaya gora
# Processing Record 3 of Set 13 | banda aceh
# Processing Record 4 of Set 13 | iquitos
# Processing Record 5 of Set 13 | axim
# Processing Record 6 of Set 13 | praia da vitoria
# Processing Record 7 of Set 13 | asyut
# Processing Record 8 of Set 13 | jajce
# Processing Record 9 of Set 13 | kloulklubed
# Processing Record 10 of Set 13 | mikhaylovskoye
# Processing Record 11 of Set 13 | matay
# Processing Record 12 of Set 13 | vila franca do campo
# Processing Record 13 of Set 13 | naryan-mar
# Processing Record 14 of Set 13 | bana
# Processing Record 15 of Set 13 | ust-nera
# Processing Record 16 of Set 13 | acajutla
# Processing Record 17 of Set 13 | veraval
# Processing Record 18 of Set 13 | barillas
# Processing Record 19 of Set 13 | takoradi
# Processing Record 20 of Set 13 | bougouni
# Processing Record 21 of Set 13 | waipawa
# Processing Record 22 of Set 13 | juifang
# City 'Juifang' not found. Skipping...
# Processing Record 23 of Set 13 | ravar
# Processing Record 24 of Set 13 | mergui
# City 'Mergui' not found. Skipping...
# Processing Record 25 of Set 13 | svetlogorsk
# Processing Record 26 of Set 13 | acapulco
# Processing Record 27 of Set 13 | tecoanapa
# Processing Record 28 of Set 13 | falealupo
# City 'Falealupo' not found. Skipping...
# Processing Record 29 of Set 13 | ekibastuz
# Processing Record 30 of Set 13 | portland
# Processing Record 31 of Set 13 | bubaque
# Processing Record 32 of Set 13 | winnemucca
# Processing Record 33 of Set 13 | lipno
# Processing Record 34 of Set 13 | ust-bolsheretsk
# City 'Ust-Bolsheretsk' not found. Skipping...
# Processing Record 35 of Set 13 | ballina
# Processing Record 36 of Set 13 | chara
# Processing Record 37 of Set 13 | angoche
# Processing Record 38 of Set 13 | tawang
# Processing Record 39 of Set 13 | ullal
# Processing Record 40 of Set 13 | basoko
# Processing Record 41 of Set 13 | mosquera
# Processing Record 42 of Set 13 | ust-kamchatsk
# City 'Ust-Kamchatsk' not found. Skipping...
# Processing Record 43 of Set 13 | camacha
# Processing Record 44 of Set 13 | sauda
# Processing Record 45 of Set 13 | dinsor
# City 'Dinsor' not found. Skipping...
# Processing Record 46 of Set 13 | kirakira
# Processing Record 47 of Set 13 | wahran
# City 'Wahran' not found. Skipping...
# Processing Record 48 of Set 13 | ruidoso
# Processing Record 49 of Set 13 | samusu
# City 'Samusu' not found. Skipping...
# Processing Record 50 of Set 13 | vysokogornyy
# Processing Record 1 of Set 14 | sangar
# Processing Record 2 of Set 14 | mantua
# Processing Record 3 of Set 14 | gurgan
# City 'Gurgan' not found. Skipping...
# Processing Record 4 of Set 14 | himora
# City 'Himora' not found. Skipping...
# Processing Record 5 of Set 14 | iglino
# Processing Record 6 of Set 14 | noumea
# Processing Record 7 of Set 14 | diffa
# Processing Record 8 of Set 14 | kautokeino
# Processing Record 9 of Set 14 | mackay
# Processing Record 10 of Set 14 | kawalu
# Processing Record 11 of Set 14 | awjilah
# Processing Record 12 of Set 14 | gannan
# Processing Record 13 of Set 14 | jackson
# Processing Record 14 of Set 14 | lazaro cardenas
# Processing Record 15 of Set 14 | mbanza-ngungu
# Processing Record 16 of Set 14 | tiznit
# Processing Record 17 of Set 14 | coahuayana
# Processing Record 18 of Set 14 | belaya gora
# Processing Record 19 of Set 14 | dengzhou
# Processing Record 20 of Set 14 | bereda
# Processing Record 21 of Set 14 | boudry
# Processing Record 22 of Set 14 | vila velha
# Processing Record 23 of Set 14 | kampot
# Processing Record 24 of Set 14 | juegang
# Processing Record 25 of Set 14 | lata
# Processing Record 26 of Set 14 | kudahuvadhoo
# Processing Record 27 of Set 14 | muroto
# Processing Record 28 of Set 14 | sabla
# Processing Record 29 of Set 14 | dauriya
# Processing Record 30 of Set 14 | naze
# Processing Record 31 of Set 14 | rio pardo
# Processing Record 32 of Set 14 | medea
# Processing Record 33 of Set 14 | mayo
# Processing Record 34 of Set 14 | tiarei
# Processing Record 35 of Set 14 | ayan
# Processing Record 36 of Set 14 | rewa
# Processing Record 37 of Set 14 | kiboga
# Processing Record 38 of Set 14 | san rafael del sur
# Processing Record 39 of Set 14 | havre-saint-pierre
# Processing Record 40 of Set 14 | san joaquin
# Processing Record 41 of Set 14 | sao joao da barra
# Processing Record 42 of Set 14 | mlonggo
# Processing Record 43 of Set 14 | minas
# Processing Record 44 of Set 14 | la libertad
# Processing Record 45 of Set 14 | adelaide
# Processing Record 46 of Set 14 | assiniboia
# Processing Record 47 of Set 14 | karratha
# Processing Record 48 of Set 14 | vitimskiy
# City 'Vitimskiy' not found. Skipping...
# Processing Record 49 of Set 14 | tonj
# Processing Record 50 of Set 14 | hay river
# Processing Record 1 of Set 15 | bo
# City 'Bo' not found. Skipping...
# Processing Record 2 of Set 15 | jurmala
# Processing Record 3 of Set 15 | yokadouma
# Processing Record 4 of Set 15 | manta
# Processing Record 5 of Set 15 | prince rupert
# Processing Record 6 of Set 15 | nouadhibou
# Processing Record 7 of Set 15 | byron bay
# Processing Record 8 of Set 15 | roseto degli abruzzi
# Processing Record 9 of Set 15 | kollam
# Processing Record 10 of Set 15 | hovd
# Processing Record 11 of Set 15 | yangjiang
# Processing Record 12 of Set 15 | kurilsk
# Processing Record 13 of Set 15 | brae
# Processing Record 14 of Set 15 | lembeni
# Processing Record 15 of Set 15 | mumford
# Processing Record 16 of Set 15 | teluk nibung
# Processing Record 17 of Set 15 | mrirt
# City 'Mrirt' not found. Skipping...
# Processing Record 18 of Set 15 | emmett
# Processing Record 19 of Set 15 | wagar
# Processing Record 20 of Set 15 | zhezkazgan
# Processing Record 21 of Set 15 | beringovskiy
# Processing Record 22 of Set 15 | mount isa
# Processing Record 23 of Set 15 | jiwani
# Processing Record 24 of Set 15 | tabou
# Processing Record 25 of Set 15 | haines junction
# Processing Record 26 of Set 15 | lahij
# Processing Record 27 of Set 15 | neepawa
# Processing Record 28 of Set 15 | palu
# Processing Record 29 of Set 15 | kamaishi
# Processing Record 30 of Set 15 | hamadan
# Processing Record 31 of Set 15 | belyy yar
# Processing Record 32 of Set 15 | half moon bay
# Processing Record 33 of Set 15 | tarko-sale
# Processing Record 34 of Set 15 | sept-iles
# Processing Record 35 of Set 15 | azimur
# City 'Azimur' not found. Skipping...
# Processing Record 36 of Set 15 | lubango
# Processing Record 37 of Set 15 | gusau
# Processing Record 38 of Set 15 | mezhdurechenskiy
# Processing Record 39 of Set 15 | mahajanga
# Processing Record 40 of Set 15 | ende
# Processing Record 41 of Set 15 | bolshaya orlovka
# City 'Bolshaya Orlovka' not found. Skipping...
# Processing Record 42 of Set 15 | samalaeulu
# City 'Samalaeulu' not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
#city_data_df.head(10)

# %%
# Reorder the columns of the city_data_df DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Atuona      PF  -9.8000 -139.0333     79.77        75          20
# 1         Pitea      SE  65.3172   21.4794     23.09        85          99
# 2     Busselton      AU -33.6500  115.3333     69.33        83          91
# 3          Biak      ID  -0.9131  122.8766     82.67        73          98
# 4   Birobidzhan      RU  48.8000  132.9500     45.39        71          29
# 5  Ornskoldsvik      SE  63.2909   18.7153     27.55        80          75
# 6        Hobart      AU -42.8794  147.3294     63.27        74          75
# 7        Camana      PE -16.6228  -72.7111     68.47        88          23
# 8         Kapaa      US  22.0752 -159.3190     78.78        92          75
# 9    Bredasdorp      ZA -34.5322   20.0403     58.15        87          32
#
#    Wind Speed   Current Description
# 0       18.86            few clouds
# 1        3.00       overcast clouds
# 2       18.90       overcast clouds
# 3        2.77       overcast clouds
# 4        8.63      scattered clouds
# 5       10.36         broken clouds
# 6        9.22            light rain
# 7        6.98            few clouds
# 8       26.46  heavy intensity rain
# 9        1.92      scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
